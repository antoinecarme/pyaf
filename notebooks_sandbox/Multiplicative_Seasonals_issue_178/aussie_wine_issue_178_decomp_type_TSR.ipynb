# %%
# work notebook for the issue : 
# Add Multiplicative Models/Seasonals #178 
# https://github.com/antoinecarme/pyaf/issues/178


gDecompositionType = "TSR"

import pyaf.ForecastEngine as autof
import pyaf.Bench.TS_datasets as tsds

import pandas as pd

df = pd.read_csv("../../data/monthly-australian-wine-sales.csv")

import datetime
df['month'] = df['month'].apply(lambda x : datetime.datetime.strptime(x, "%Y-%m-%d"))

#df.tail(10)
#df[:-10].tail()
#df[:-10:-1]
#df.describe()

# %%
df, df.plot(x='month', y='sales')
# Out:
# (         month  sales
#  0   1980-01-01  15136
#  1   1980-02-01  16733
#  2   1980-03-01  20016
#  3   1980-04-01  17708
#  4   1980-05-01  18019
#  ..         ...    ...
#  171 1994-04-01  26323
#  172 1994-05-01  23779
#  173 1994-06-01  27549
#  174 1994-07-01  29660
#  175 1994-08-01  23356
#
#  [176 rows x 2 columns],
#  <AxesSubplot:xlabel='month'>)

# %%
lEngine = autof.cForecastEngine()
lEngine.mOptions.set_active_decomposition_types([ gDecompositionType ]);

lEngine

H = 24
# lEngine.mOptions.enable_slow_mode();
# lEngine.mOptions.mDebugPerformance = True;
lEngine.train(df , "month" , "sales", H);
lEngine.getModelInfo();
print(lEngine.mSignalDecomposition.mTrPerfDetails.head());

lEngine.mSignalDecomposition.mBestModel.mTimeInfo.mResolution

lEngine.standardPlots();
# Out:
# INFO:pyaf.std:START_TRAINING 'sales'
# /home/antoine/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# /home/antoine/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# INFO:pyaf.std:END_TRAINING_TIME_IN_SECONDS '['sales']' 2.017630100250244
# INFO:pyaf.std:TIME_DETAIL TimeVariable='month' TimeMin=1980-01-01T00:00:00.000000 TimeMax=1990-01-01T00:00:00.000000 TimeDelta=<DateOffset: months=1> Horizon=24
# INFO:pyaf.std:SIGNAL_DETAIL_ORIG SignalVariable='sales' Length=176  Min=13652 Max=40226  Mean=25392.147727272728 StdDev=5325.627485521334
# INFO:pyaf.std:SIGNAL_DETAIL_TRANSFORMED TransformedSignalVariable='_sales' Min=13652 Max=40226  Mean=25392.147727272728 StdDev=5325.627485521334
# INFO:pyaf.std:DECOMPOSITION_TYPE 'TSR'
# INFO:pyaf.std:BEST_TRANSOFORMATION_TYPE '_'
# INFO:pyaf.std:BEST_DECOMPOSITION  '_sales_ConstantTrend_residue_zeroCycle[1.0]_residue_NoAR' [ConstantTrend * NoCycle * NoAR]
# INFO:pyaf.std:TREND_DETAIL '_sales_ConstantTrend' [ConstantTrend]
# INFO:pyaf.std:CYCLE_DETAIL '_sales_ConstantTrend_residue_zeroCycle[1.0]' [NoCycle]
# INFO:pyaf.std:AUTOREG_DETAIL '_sales_ConstantTrend_residue_zeroCycle[1.0]_residue_NoAR' [NoAR]
# INFO:pyaf.std:MODEL_MAPE MAPE_Fit=0.1743 MAPE_Forecast=0.1546 MAPE_Test=0.164
# INFO:pyaf.std:MODEL_SMAPE SMAPE_Fit=0.1667 SMAPE_Forecast=0.1489 SMAPE_Test=0.1573
# INFO:pyaf.std:MODEL_MASE MASE_Fit=0.8729 MASE_Forecast=0.8081 MASE_Test=0.7518
# INFO:pyaf.std:MODEL_CRPS CRPS_Fit=608.4341126972201 CRPS_Forecast=541.8102479338843 CRPS_Test=528.4870867768592
# INFO:pyaf.std:MODEL_L1 L1_Fit=4207.703572160372 L1_Forecast=3777.6355638496398 L1_Test=4042.9831267217633
# INFO:pyaf.std:MODEL_L2 L2_Fit=5367.801176012434 L2_Forecast=5048.350951976265 L2_Test=5476.569968057899
# INFO:pyaf.std:MODEL_LnQ LnQ_Fit=5.484474949509648 LnQ_Forecast=1.2268606987754511 LnQ_Test=1.1533007652595861
# INFO:pyaf.std:MODEL_MEDIAN_AE MedAE_Fit=3386.7024793388446 MedAE_Forecast=2915.7024793388446 MedAE_Test=2477.7024793388446
# INFO:pyaf.std:MODEL_COMPLEXITY 2
# INFO:pyaf.std:SIGNAL_TRANSFORMATION_DETAIL_START
# INFO:pyaf.std:SIGNAL_TRANSFORMATION_MODEL_VALUES NoTransf None
# INFO:pyaf.std:SIGNAL_TRANSFORMATION_DETAIL_END
# INFO:pyaf.std:TREND_DETAIL_START
# INFO:pyaf.std:CONSTANT_TREND ConstantTrend 25231.702479338845
# INFO:pyaf.std:TREND_DETAIL_END
# INFO:pyaf.std:CYCLE_MODEL_DETAIL_START
# INFO:pyaf.std:ZERO_CYCLE_MODEL_VALUES _sales_ConstantTrend_residue_zeroCycle[1.0] 1.0 {}
# INFO:pyaf.std:CYCLE_MODEL_DETAIL_END
# INFO:pyaf.std:AR_MODEL_DETAIL_START
# INFO:pyaf.std:AR_MODEL_DETAIL_END
# INFO:pyaf.std:START_PLOTTING
#   Split Transformation DecompositionType  \
# 0  None         _sales               TSR
# 1  None   CumSum_sales               TSR
# 2  None         _sales               TSR
# 3  None   CumSum_sales               TSR
# 4  None   CumSum_sales               TSR
#
#                                                Model  \
# 0  _sales_ConstantTrend_residue_zeroCycle[1.0]_re...
# 1  CumSum_sales_LinearTrend_residue_zeroCycle[1.0...
# 2  _sales_PolyTrend_residue_zeroCycle[1.0]_residu...
# 3  CumSum_sales_PolyTrend_residue_zeroCycle[1.0]_...
# 4  CumSum_sales_ConstantTrend_residue_zeroCycle[1...
#
#                                      DetailedFormula  \
# 0  (_sales, TSR, None, _sales_ConstantTrend_resid...
# 1  (CumSum_sales, TSR, None, CumSum_sales_LinearT...
# 2  (_sales, TSR, None, _sales_PolyTrend_residue_z...
# 3  (CumSum_sales, TSR, None, CumSum_sales_PolyTre...
# 4  (CumSum_sales, TSR, None, CumSum_sales_Constan...
#
#                                Category  Complexity  FitMAPE  ForecastMAPE  \
# 0   NoTransf_ConstantTrend_NoCycle_NoAR           2   0.1743        0.1546
# 1  Integration_LinearTrend_NoCycle_NoAR           4   0.1895        0.1560
# 2       NoTransf_PolyTrend_NoCycle_NoAR           5   0.1592        0.1682
# 3      Integration_PolyTrend_NoCycle_AR          36   0.1890        0.1778
# 4  Integration_ConstantTrend_NoCycle_AR          33   0.2053        0.1849
#
#    TestMAPE
# 0    0.1640
# 1    0.1822
# 2    0.1698
# 3    0.2115
# 4    0.2236
# INFO:pyaf.std:END_PLOTTING_TIME_IN_SECONDS 1.8109807968139648

# %%
dfapp_in = df.copy();
dfapp_in.tail()

#H = 12
dfapp_out = lEngine.forecast(dfapp_in, H);
#dfapp_out.to_csv("outputs/ozone_apply_out.csv")
dfapp_out.tail(2 * H)
print("Forecast Columns " , dfapp_out.columns);
Forecast_DF = dfapp_out[['month' , 'sales', 'sales' + '_Forecast']]
print(Forecast_DF.info())
print("Forecasts\n" , Forecast_DF.tail(H));

print("\n\n<ModelInfo>")
print(lEngine.to_json());
print("</ModelInfo>\n\n")
print("\n\n<Forecast>")
print(Forecast_DF.tail(2*H).to_json(date_format='iso'))
print("</Forecast>\n\n")
# Out:
# INFO:pyaf.std:START_FORECASTING '['sales']'
# INFO:pyaf.std:END_FORECAST_TIME_IN_SECONDS  '['sales']' 0.32891082763671875
# Forecast Columns  Index(['month', 'sales', 'row_number', 'month_Normalized', '_sales',
#        '_sales_ConstantTrend', '_sales_ConstantTrend_residue',
#        '_sales_ConstantTrend_residue_zeroCycle[1.0]',
#        '_sales_ConstantTrend_residue_zeroCycle[1.0]_residue',
#        '_sales_ConstantTrend_residue_zeroCycle[1.0]_residue_NoAR',
#        '_sales_ConstantTrend_residue_zeroCycle[1.0]_residue_NoAR_residue',
#        '_sales_Trend', '_sales_Trend_residue', '_sales_Cycle',
#        '_sales_Cycle_residue', '_sales_AR', '_sales_AR_residue',
#        '_sales_TransformedForecast', 'sales_Forecast',
#        '_sales_TransformedResidue', 'sales_Residue',
#        'sales_Forecast_Lower_Bound', 'sales_Forecast_Upper_Bound',
#        'sales_Forecast_Quantile_10', 'sales_Forecast_Quantile_30',
#        'sales_Forecast_Quantile_50', 'sales_Forecast_Quantile_70',
#        'sales_Forecast_Quantile_90'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month           200 non-null    datetime64[ns]
#  1   sales           176 non-null    float64
#  2   sales_Forecast  200 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 4.8 KB
# None
# Forecasts
#           month  sales  sales_Forecast
# 176 1994-09-01    NaN    25231.702479
# 177 1994-10-01    NaN    25231.702479
# 178 1994-11-01    NaN    25231.702479
# 179 1994-12-01    NaN    25231.702479
# 180 1995-01-01    NaN    25231.702479
# 181 1995-02-01    NaN    25231.702479
# 182 1995-03-01    NaN    25231.702479
# 183 1995-04-01    NaN    25231.702479
# 184 1995-05-01    NaN    25231.702479
# 185 1995-06-01    NaN    25231.702479
# 186 1995-07-01    NaN    25231.702479
# 187 1995-08-01    NaN    25231.702479
# 188 1995-09-01    NaN    25231.702479
# 189 1995-10-01    NaN    25231.702479
# 190 1995-11-01    NaN    25231.702479
# 191 1995-12-01    NaN    25231.702479
# 192 1996-01-01    NaN    25231.702479
# 193 1996-02-01    NaN    25231.702479
# 194 1996-03-01    NaN    25231.702479
# 195 1996-04-01    NaN    25231.702479
# 196 1996-05-01    NaN    25231.702479
# 197 1996-06-01    NaN    25231.702479
# 198 1996-07-01    NaN    25231.702479
# 199 1996-08-01    NaN    25231.702479
#
#
# <ModelInfo>
# {
#     "sales": {
#         "Dataset": {
#             "Signal": "sales",
#             "Time": {
#                 "Horizon": 24,
#                 "TimeMinMax": [
#                     "1980-01-01 00:00:00",
#                     "1994-08-01 00:00:00"
#                 ],
#                 "TimeVariable": "month"
#             },
#             "Training_Signal_Length": 176
#         },
#         "Model": {
#             "AR_Model": "NoAR",
#             "Best_Decomposition": "_sales_ConstantTrend_residue_zeroCycle[1.0]_residue_NoAR",
#             "Cycle": "NoCycle",
#             "Signal_Decomposition_Type": "TSR",
#             "Signal_Transoformation": "NoTransf",
#             "Trend": "ConstantTrend"
#         },
#         "Model_Performance": {
#             "COMPLEXITY": 2,
#             "CRPS": 541.8102479338843,
#             "LnQ": 1.2268606987754511,
#             "MAE": 3777.6355638496398,
#             "MAPE": 0.1546,
#             "MASE": 0.8081,
#             "MedAE": 2915.7024793388446,
#             "RMSE": 5048.350951976265
#         }
#     }
# }
# </ModelInfo>
#
#
#
#
# <Forecast>
# {"month":{"152":"1992-09-01T00:00:00.000Z","153":"1992-10-01T00:00:00.000Z","154":"1992-11-01T00:00:00.000Z","155":"1992-12-01T00:00:00.000Z","156":"1993-01-01T00:00:00.000Z","157":"1993-02-01T00:00:00.000Z","158":"1993-03-01T00:00:00.000Z","159":"1993-04-01T00:00:00.000Z","160":"1993-05-01T00:00:00.000Z","161":"1993-06-01T00:00:00.000Z","162":"1993-07-01T00:00:00.000Z","163":"1993-08-01T00:00:00.000Z","164":"1993-09-01T00:00:00.000Z","165":"1993-10-01T00:00:00.000Z","166":"1993-11-01T00:00:00.000Z","167":"1993-12-01T00:00:00.000Z","168":"1994-01-01T00:00:00.000Z","169":"1994-02-01T00:00:00.000Z","170":"1994-03-01T00:00:00.000Z","171":"1994-04-01T00:00:00.000Z","172":"1994-05-01T00:00:00.000Z","173":"1994-06-01T00:00:00.000Z","174":"1994-07-01T00:00:00.000Z","175":"1994-08-01T00:00:00.000Z","176":"1994-09-01T00:00:00.000Z","177":"1994-10-01T00:00:00.000Z","178":"1994-11-01T00:00:00.000Z","179":"1994-12-01T00:00:00.000Z","180":"1995-01-01T00:00