# %%
import pandas as pd
import numpy as np

import pyaf.ForecastEngine as autof
import pyaf.Bench.TS_datasets as tsds


# %matplotlib inline

# %%
b1 = tsds.load_ozone()
df = b1.mPastData
# Out:
#      Month  Ozone       Time
# 0  1955-01    2.7 1955-01-01
# 1  1955-02    2.0 1955-02-01
# 2  1955-03    3.6 1955-03-01
# 3  1955-04    5.0 1955-04-01
# 4  1955-05    6.5 1955-05-01

# %%
b1.mHorizon
# Out:
# 12

# %%
lEngine = autof.cForecastEngine()

# %%
lEngine.mOptions.mModelSelection_Criterion = 'CRPS'
lEngine.train(df , b1.mTimeVar , b1.mSignalVar, b1.mHorizon);
lEngine.getModelInfo();
print(lEngine.mSignalDecomposition.mTrPerfDetails.head());
lEngine.standardPlots()
# Out:
# INFO:pyaf.std:START_TRAINING 'Ozone'
# INFO:pyaf.std:END_TRAINING_TIME_IN_SECONDS '['Ozone']' 7.037970066070557
# INFO:pyaf.std:TIME_DETAIL TimeVariable='Time' TimeMin=1955-01-01T00:00:00.000000 TimeMax=1967-09-01T00:00:00.000000 TimeDelta=<DateOffset: months=1> Horizon=12
# INFO:pyaf.std:SIGNAL_DETAIL_ORIG SignalVariable='Ozone' Length=204  Min=1.2 Max=8.7  Mean=3.8357843137254894 StdDev=1.491559215940118
# INFO:pyaf.std:SIGNAL_DETAIL_TRANSFORMED TransformedSignalVariable='_Ozone' Min=1.2 Max=8.7  Mean=3.8357843137254894 StdDev=1.491559215940118
# INFO:pyaf.std:BEST_TRANSOFORMATION_TYPE '_'
# INFO:pyaf.std:BEST_DECOMPOSITION  '_Ozone_LinearTrend_residue_zeroCycle_residue_NoAR' [LinearTrend + NoCycle + NoAR]
# INFO:pyaf.std:TREND_DETAIL '_Ozone_LinearTrend' [LinearTrend]
# INFO:pyaf.std:CYCLE_DETAIL '_Ozone_LinearTrend_residue_zeroCycle' [NoCycle]
# INFO:pyaf.std:AUTOREG_DETAIL '_Ozone_LinearTrend_residue_zeroCycle_residue_NoAR' [NoAR]
# INFO:pyaf.std:MODEL_MAPE MAPE_Fit=0.3472 MAPE_Forecast=0.3191 MAPE_Test=0.3197
# INFO:pyaf.std:MODEL_SMAPE SMAPE_Fit=0.2955 SMAPE_Forecast=0.2944 SMAPE_Test=0.265
# INFO:pyaf.std:MODEL_MASE MASE_Fit=1.3082 MASE_Forecast=1.1567 MASE_Test=1.3455
# INFO:pyaf.std:MODEL_CRPS CRPS_Fit=0.21372173326516924 CRPS_Forecast=0.1204583504096602 CRPS_Test=0.12104891675063584
# INFO:pyaf.std:MODEL_L1 L1_Fit=1.149813399317256 L1_Forecast=0.8979604351062586 L1_Test=0.6360316077716476
# INFO:pyaf.std:MODEL_L2 L2_Fit=1.4040034516565727 L2_Forecast=1.1010807964604632 L2_Test=0.7393492970728309
# INFO:pyaf.std:MODEL_COMPLEXITY 16
# INFO:pyaf.std:SIGNAL_TRANSFORMATION_DETAIL_START
# INFO:pyaf.std:SIGNAL_TRANSFORMATION_MODEL_VALUES NoTransf None
# INFO:pyaf.std:SIGNAL_TRANSFORMATION_DETAIL_END
# INFO:pyaf.std:TREND_DETAIL_START
# INFO:pyaf.std:LINEAR_RIDGE_TREND LinearTrend (5.022578136250887, array([-1.82712926]))
# INFO:pyaf.std:TREND_DETAIL_END
# INFO:pyaf.std:CYCLE_MODEL_DETAIL_START
# INFO:pyaf.std:ZERO_CYCLE_MODEL_VALUES _Ozone_LinearTrend_residue_zeroCycle 0.0 {}
# INFO:pyaf.std:CYCLE_MODEL_DETAIL_END
# INFO:pyaf.std:AR_MODEL_DETAIL_START
# INFO:pyaf.std:AR_MODEL_DETAIL_END
# INFO:pyaf.std:START_PLOTTING
#   Split Transformation                                              Model  \
# 0  None         _Ozone  _Ozone_LinearTrend_residue_zeroCycle_residue_NoAR
# 1  None         _Ozone  _Ozone_LinearTrend_residue_bestCycle_byMAPE_re...
# 2  None     Diff_Ozone  Diff_Ozone_LinearTrend_residue_zeroCycle_resid...
# 3  None     Diff_Ozone  Diff_Ozone_LinearTrend_residue_bestCycle_byMAP...
# 4  None         _Ozone    _Ozone_PolyTrend_residue_zeroCycle_residue_NoAR
#
#                                  Category  Complexity   FitCRPS  ForecastCRPS  \
# 0       NoTransf_LinearTrend_NoCycle_NoAR          16  0.213722      0.120458
# 1    NoTransf_LinearTrend_Cycle_None_NoAR          24  0.213722      0.120458
# 2     Difference_LinearTrend_NoCycle_NoAR          48  0.206043      0.139671
# 3  Difference_LinearTrend_Cycle_None_NoAR          56  0.206043      0.139671
# 4         NoTransf_PolyTrend_NoCycle_NoAR          16  0.214071      0.143447
#
#    TestCRPS
# 0  0.121049
# 1  0.121049
# 2  0.157197
# 3  0.157197
# 4  0.509586
# INFO:pyaf.std:END_PLOTTING_TIME_IN_SECONDS 1.2266120910644531

# %%
dfapp_in = df.copy();
dfapp_in.tail()

#H = 12
dfapp_out = lEngine.forecast(dfapp_in, b1.mHorizon);
#dfapp_out.to_csv("outputs/ozone_apply_out.csv")
dfapp_out.tail(2 * b1.mHorizon)
# Out:
# INFO:pyaf.std:START_FORECASTING '['Ozone']'
# INFO:pyaf.std:END_FORECAST_TIME_IN_SECONDS  '['Ozone']' 0.24042844772338867
#           Time  Ozone  row_number  Time_Normalized  _Ozone  \
# 192 1971-01-01    1.8         192         1.263294     1.8
# 193 1971-02-01    2.0         193         1.269996     2.0
# 194 1971-03-01    2.2         194         1.276048     2.2
# 195 1971-04-01    3.0         195         1.282750     3.0
# 196 1971-05-01    2.4         196         1.289235     2.4
# 197 1971-06-01    3.5         197         1.295936     3.5
# 198 1971-07-01    3.5         198         1.302421     3.5
# 199 1971-08-01    3.3         199         1.309122     3.3
# 200 1971-09-01    2.7         200         1.315824     2.7
# 201 1971-10-01    2.5         201         1.322309     2.5
# 202 1971-11-01    1.6         202         1.329010     1.6
# 203 1971-12-01    1.2         203         1.335495     1.2
# 204 1972-01-01    NaN         204         1.342196     NaN
# 205 1972-02-01    NaN         205         1.348898     NaN
# 206 1972-03-01    NaN         206         1.355166     NaN
# 207 1972-04-01    NaN         207         1.361868     NaN
# 208 1972-05-01    NaN         208         1.368353     NaN
# 209 1972-06-01    NaN         209         1.375054     NaN
# 210 1972-07-01    NaN         210         1.381539     NaN
# 211 1972-08-01    NaN         211         1.388240     NaN
# 212 1972-09-01    NaN         212         1.394942     NaN
# 213 1972-10-01    NaN         213         1.401427     NaN
# 214 1972-11-01    NaN         214         1.408128     NaN
# 215 1972-12-01    NaN         215         1.414613     NaN
#
#      _Ozone_LinearTrend  _Ozone_LinearTrend_residue  \
# 192            2.714376                   -0.914376
# 193            2.702132                   -0.702132
# 194            2.691073                   -0.491073
# 195            2.678829                    0.321171
# 196            2.666980                   -0.266980
# 197            2.654736                    0.845264
# 198            2.642886                    0.857114
# 199            2.630642                    0.669358
# 200            2.618398                    0.081602
# 201            2.606549                   -0.106549
# 202            2.594305                   -0.994305
# 203            2.582456                   -1.382456
# 204            2.570212                         NaN
# 205            2.557968                         NaN
# 206            2.546514                         NaN
# 207            2.534270                         NaN
# 208            2.522421                         NaN
# 209            2.510177                         NaN
# 210            2.498328                         NaN
# 211            2.486084                         NaN
# 212            2.473839                         NaN
# 213            2.461990                         NaN
# 214            2.449746                         NaN
# 215            2.437897                         NaN
#
#      _Ozone_LinearTrend_residue_zeroCycle  \
# 192                                   0.0
# 193                                   0.0
# 194                                   0.0
# 195                                   0.0
# 196                                   0.0
# 197                                   0.0
# 198                                   0.0
# 199                                   0.0
# 200                                   0.0
# 201                                   0.0
# 202                                   0.0
# 203                                   0.0
# 204                                   0.0
# 205                                   0.0
# 206                                   0.0
# 207                                   0.0
# 208                                   0.0
# 209                                   0.0
# 210                                   0.0
# 211                                   0.0
# 212                                   0.0
# 213                                   0.0
# 214                                   0.0
# 215                                   0.0
#
#      _Ozone_LinearTrend_residue_zeroCycle_residue  \
# 192                                     -0.914376
# 193                                     -0.702132
# 194                                     -0.491073
# 195                                      0.321171
# 196                                     -0.266980
# 197                                      0.845264
# 198                                      0.857114
# 199                                      0.669358
# 200                                      0.081602
# 201                                     -0.106549
# 202                                     -0.994305
# 203                                     -1.382456
# 204                                           NaN
# 205                                           NaN
# 206                                           NaN
# 207                                           NaN
# 208                                           NaN
# 209                                           NaN
# 210                                           NaN
# 211                                           NaN
# 212                                           NaN
# 213                                           NaN
# 214                                           NaN
# 215                                           NaN
#
#      _Ozone_LinearTrend_residue_zeroCycle_residue_NoAR  ...  Ozone_Forecast  \
# 192                                                0.0  ...        2.714376
# 193                                                0.0  ...        2.702132
# 194                                                0.0  ...        2.691073
# 195                                                0.0  ...        2.678829
# 196                                                0.0  ...        2.666980
# 197                                                0.0  ...        2.654736
# 198                                                0.0  ...        2.642886
# 199                                                0.0  ...        2.630642
# 200                                                0.0  ...        2.618398
# 201                                                0.0  ...        2.606549
# 202                                                0.0  ...        2.594305
# 203                                                0.0  ...        2.582456
# 204                                                0.0  ...        2.570212
# 205                                                0.0  ...        2.557968
# 206                                                0.0  ...        2.546514
# 207                                                0.0  ...        2.534270
# 208                                                0.0  ...        2.522421
# 209                                                0.0  ...        2.510177
# 210                                                0.0  ...        2.498328
# 211                                                0.0  ...        2.486084
# 212                                                0.0  ...        2.473839
# 213                                                0.0  ...        2.461990
# 214                                                0.0  ...        2.449746
# 215                                                0.0  ...        2.437897
#
#      _Ozone_TransformedResidue  Ozone_Residue  Ozone_Forecast_Lower_Bound  \
# 192                  -0.914376      -0.914376                         NaN
# 193                  -0.702132      -0.702132                         NaN
# 194                  -0.491073      -0.491073                         NaN
# 195                   0.321171       0.321171                         NaN
# 196                  -0.266980      -0.266980                         NaN
# 197                   0.845264       0.845264                         NaN
# 198                   0.857114       0.857114                         NaN
# 199                   0.669358       0.669358                         NaN
# 200                   0.081602       0.081602                         NaN
# 201                  -0.106549      -0.106549                         NaN
# 202                  -0.994305      -0.994305                         NaN
# 203                  -1.382456      -1.382456                         NaN
# 204                        NaN            NaN                    0.412094
# 205                        NaN            NaN                    0.399850
# 206                        NaN            NaN                    0.388396
# 207                        NaN            NaN                    0.376151
# 208                        NaN            NaN                    0.364302
# 209                        NaN            NaN                    0.352058
# 210                        NaN            NaN                    0.340209
# 211                        NaN            NaN                    0.327965
# 212                        NaN            NaN                    0.315721
# 213                        NaN            NaN                    0.303872
# 214                        NaN            NaN                    0.291628
# 215                        NaN            NaN                    0.279779
#
#      Ozone_Forecast_Upper_Bound  Ozone_Forecast_Quantile_10  \
# 192                         NaN                         NaN
# 193                         NaN                         NaN
# 194                         NaN                         NaN
# 195                         NaN                         NaN
# 196                         NaN                         NaN
# 197                         NaN                         NaN
# 198                         NaN                         NaN
# 199                         NaN                         NaN
# 200                         NaN                         NaN
# 201                         NaN                         NaN
# 202                         NaN                         NaN
# 203                         NaN                         NaN
# 204                    4.728330                    0.743027
# 205                    4.716086                    0.730783
# 206                    4.704632                    0.719329
# 207                    4.692388                    0.707085
# 208                    4.680539                    0.695236
# 209                    4.668295                    0.682992
# 210                    4.656446                    0.671143
# 211                    4.644202                    0.658898
# 212                    4.631958                    0.646654
# 213                    4.620109                    0.634805
# 214                    4.607865                    0.622561
# 215                    4.596016                    0.610712
#
#      Ozone_Forecast_Quantile_30  Ozone_Forecast_Quantile_50  \
# 192                         NaN                         NaN
# 193                         NaN                         NaN
# 194                         NaN                         NaN
# 195                         NaN                         NaN
# 196                         NaN                         NaN
# 197                         NaN                         NaN
# 198                         NaN                         NaN
# 199                         NaN                         NaN
# 200                         NaN                         NaN
# 201                         NaN                         NaN
# 202                         NaN                         NaN
# 203                         NaN                         NaN
# 204                    1.772514                    2.369111
# 205                    1.760270                    2.356867
# 206                    1.748816                    2.345413
# 207                    1.736572                    2.333169
# 208                    1.724723                    2.321320
# 209                    1.712479                    2.309076
# 210                    1.700630                    2.297227
# 211                    1.688386                    2.284983
# 212                    1.676142                    2.272739
# 213                    1.664293                    2.260890
# 214                    1.652049                    2.248646
# 215                    1.640200                    2.236797
#
#      Ozone_Forecast_Quantile_70  Ozone_Forecast_Quantile_90
# 192                         NaN                         NaN
# 193                         NaN                         NaN
# 194                         NaN                         NaN
# 195                         NaN                         NaN
# 196                         NaN                         NaN
# 197                         NaN                         NaN
# 198                         NaN                         NaN
# 199                         NaN                         NaN
# 200                         NaN                         NaN
# 201                         NaN                         NaN
# 202                         NaN                         NaN
# 203                         NaN                         NaN
# 204                    3.020649                    3.800262
# 205                    3.008405                    3.788018
# 206                    2.996951                    3.776564
# 207                    2.984707                    3.764320
# 208                    2.972858                    3.752471
# 209                    2.960614                    3.740227
# 210                    2.948764                    3.728378
# 211                    2.936520                    3.716134
# 212                    2.924276                    3.703890
# 213                    2.912427                    3.692041
# 214                    2.900183                    3.679796
# 215                    2.888334                    3.667947
#
# [24 rows x 28 columns]
